# %% [markdown]
# <a href="https://colab.research.google.com/github/catabia/indeed/blob/main/wash_indeed_5_15_21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://content.lib.washington.edu/projects/sea15/index.html
# https://lni.wa.gov/workers-rights/wages/minimum-wage/history-of-washington-states-minimum-wage

# %%
import pandas as pd
from matplotlib import pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure
import seaborn as sns
import numpy as np
import math
from matplotlib import dates

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("/content/drive/MyDrive/hannah_research/data/indeed_wa_05_31_21.csv")
df.shape
# Out:
# (42496, 47)

# %%
#pandas!
pd.set_option('display.max_rows', 500) 

#dates!
df['review_date'] = pd.to_datetime(df['review_date'])
df.set_index(pd.DatetimeIndex(df['review_date']))

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42496 entries, 0 to 42495
# Data columns (total 47 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   platform              42496 non-null  object
#  1   scrape_company_num    42496 non-null  int64
#  2   date_scraped          42496 non-null  object
#  3   scrape_folder_name    42496 non-null  object
#  4   scrape_file_name      42496 non-null  object
#  5   base_url              42496 non-null  object
#  6   page_num              42496 non-null  int64
#  7   parent_company        42496 non-null  object
#  8   be_careful            42496 non-null  int64
#  9   company_name          42496 non-null  object
#  10  scraped_from_url      42496 non-null  object
#  11  empid                 42496 non-null  object
#  12  language              0 non-null      float64
#  13  id                    42496 non-null  object
#  14  review_url            42496 non-null  object
#  15  uid                   42496 non-null  object
#  16  review_date           42496 non-null  datetime64[ns]
#  17  review_month          42496 non-null  int64
#  18  review_day            42496 non-null  int64
#  19  review_year           42496 non-null  int64
#  20  parsable_loc          42496 non-null  int64
#  21  state                 42496 non-null  object
#  22  city                  42496 non-null  object
#  23  country               42496 non-null  object
#  24  location              42496 non-null  object
#  25  job_title             42488 non-null  object
#  26  norm_job_title        42263 non-null  object
#  27  current               42496 non-null  int64
#  28  length_of_employment  0 non-null      float64
#  29  overall_rating        42496 non-null  int64
#  30  work_life_rating      42496 non-null  int64
#  31  compensation_rating   42496 non-null  int64
#  32  job_security_rating   42496 non-null  int64
#  33  management_rating     42496 non-null  int64
#  34  culture_rating        42496 non-null  int64
#  35  review_title          42454 non-null  object
#  36  review_text           42496 non-null  object
#  37  pros                  20436 non-null  object
#  38  cons                  19619 non-null  object
#  39  advice_to_management  0 non-null      float64
#  40  helpful_yes           42496 non-null  int64
#  41  helpful_no            42496 non-null  int64
#  42  recommend             0 non-null      float64
#  43  ceo_approval          0 non-null      float64
#  44  business_outlook      0 non-null      float64
#  45  redacted              42496 non-null  int64
#  46  is_deletable          42496 non-null  int64
# dtypes: datetime64[ns](1), float64(6), int64(18), object(22)
# memory usage: 15.2+ MB

# %%
sns.countplot(data=df, x='review_year')
plt.title("Reviews in WA")
# Out:
# Text(0.5, 1.0, 'Reviews in WA')

# %%
#df = df[df.be_careful!=1]

# %%
# Cut off before 2013, after 2020

df = df[df.review_year>2012]
df = df[df.review_year<2021]
sns.countplot(data=df, x='review_year')
plt.title("Reviews in WA")
# Out:
# Text(0.5, 1.0, 'Reviews in WA')

# %%
districts = ['Seattle', 'North Seattle', 'Northgate', 'Lake City', 'North Seattle',
                'Windermere', 'Ravenna', 'University District', 'Lake Union', 'Lower Wallingford',
                'Fremont', 'Ballard', 'Central Seattle', 'Magnolia', 'Queen Anne', 'Capitol Hill',
                'Broadway', 'Stevens', 'Madison Park', 'South Lake Union', 'Central Area', 'Atlantic',
                'Madrona', 'Harrison', 'Denny-Blaine', 'South End', 'Rainier Valley', 'Columbia City',
                'Seward Park', 'Beacon Hill', 'West Seattle', 'Delridge', 'Georgetown', 'Southeast Seattle']

# %%
df['seattle'] = 0
df.loc[df.city.isin(districts),'seattle']= 1
# elimnate SeaTac for now...
print(df.shape)
df = df.drop(df[df.city=='SeaTac'].index)
print(df.shape)
# Out:
# (39931, 48)
# (39828, 48)

# %%
df['month_year'] = pd.to_datetime(df['review_date']).dt.strftime('%Y-%m')

# %%
# Cut off before 2013, after 2020
df = df[df.review_year>2012]
df = df[df.review_year<2021]
print('Total number of reviews:', df.shape[0])
print('Total reviews in Seattle:', df.seattle.sum())

data_viz = df[['month_year', 'seattle']]
data_viz = data_viz.groupby(['month_year', 'seattle']).size().reset_index(name='count')
#data_viz = data_viz.groupby(['review_year', 'seattle']).agg({'count'})

#print(data_viz)

figure(figsize=(12, 8), dpi=80)
sns.lineplot(data=data_viz, x='month_year', y='count', hue = 'seattle', linewidth=2, style = 'seattle')
plt.title("Indeed.com Data Set\nWashington State", fontsize=20)
plt.xlabel('Time', fontsize=20)
plt.ylabel('Number of Reviews', fontsize=20)
#ticks, labels = plt.xticks()

plt.xticks(ticks=[6,18,30,42,54,66,78,90], labels=['2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020'])
plt.legend(['Not Seattle: 33,858 reviews', 'Seattle: 5,970 reviews'])
# Out:
# Total number of reviews: 39828
# Total reviews in Seattle: 5970

# %%
figure(figsize=(12, 6), dpi=80)
top_jobs = df.norm_job_title.value_counts()[:10].index.tolist()
job_df = df[df.norm_job_title.isin(top_jobs)]
print(job_df.shape[0])
sns.countplot(data=job_df, x='norm_job_title', hue = 'seattle', order = top_jobs)
plt.title("Top 10 Jobs")
plt.xlabel('Job Title')
locs, labs = plt.xticks()
l= ['Cashier', 'Sales Associate', 'Crew Member', 'Customer Service\nRepresentative', 'Barista', 'Customer Service\nAssociate / Cashier', 'Retail Sales\nAssociate', 'Shift Manager', 'Associate', 'Team Member']
plt.xticks(ticks=locs, labels=l, rotation=30)
plt.ylabel('Number of Reviews')
plt.legend(['Not Seattle', 'Seattle'])
# Out:
# 13062

# %%
figure(figsize=(12, 6), dpi=80)
top_comp = df.company_name.value_counts()[:10].index.tolist()
comp_df = df[df.company_name.isin(top_comp)]
print(job_df.shape[0])
sns.countplot(data=comp_df, x='company_name', hue = 'seattle', order = top_comp)
plt.title("Top 10 Companies")
plt.xlabel('Company name')
locs, labs = plt.xticks()
plt.xticks(rotation=30)
plt.ylabel('Number of Reviews')
plt.legend(['Not Seattle', 'Seattle'])
# Out:
# 13062

# %%
comp = df.groupby(['month_year', 'seattle']).agg({'overall_rating':['mean', 'count']})
comp.columns = ['mean', 'count']
comp.reset_index(inplace=True)
comp
# Out:
#     month_year  seattle      mean  count
# 0      2013-01        0  3.874372    199
# 1      2013-01        1  3.806452     31
# 2      2013-02        0  3.684211    152
# 3      2013-02        1  3.884615     26
# 4      2013-03        0  3.861111    144
# 5      2013-03        1  3.965517     29
# 6      2013-04        0  3.772152    158
# 7      2013-04        1  3.650000     20
# 8      2013-05        0  3.768707    147
# 9      2013-05        1  3.600000     25
# 10     2013-06        0  3.672956    159
# 11     2013-06        1  3.958333     24
# 12     2013-07        0  3.708920    213
# 13     2013-07        1  3.916667     24
# 14     2013-08        0  3.654255    188
# 15     2013-08        1  3.807692     26
# 16     2013-09        0  3.631902    163
# 17     2013-09        1  4.130435     23
# 18     2013-10        0  3.752747    182
# 19     2013-10        1  3.652174     23
# 20     2013-11        0  3.759259    162
# 21     2013-11        1  3.952381     21
# 22     2013-12        0  3.625899    139
# 23     2013-12        1  3.814815     27
# 24     2014-01        0  3.585586    222
# 25     2014-01        1  3.645161     31
# 26     2014-02        0  3.674556    169
# 27     2014-02        1  3.909091     33
# 28     2014-03        0  3.729167    192
# 29     2014-03        1  3.777778     45
# 30     2014-04        0  3.834437    151
# 31     2014-04        1  3.840000     25
# 32     2014-05        0  3.803468    173
# 33     2014-05        1  4.066667     30
# 34     2014-06        0  3.701220    164
# 35     2014-06        1  3.766667     30
# 36     2014-07        0  3.712644    174
# 37     2014-07        1  3.551724     29
# 38     2014-08        0  3.658824    170
# 39     2014-08        1  3.384615     26
# 40     2014-09        0  3.721925    187
# 41     2014-09        1  3.724138     29
# 42     2014-10        0  3.812500    176
# 43     2014-10        1  4.138889     36
# 44     2014-11        0  3.733333    150
# 45     2014-11        1  4.000000     33
# 46     2014-12        0  3.604938    162
# 47     2014-12        1  3.500000     20
# 48     2015-01        0  3.763158    228
# 49     2015-01        1  3.697674     43
# 50     2015-02        0  3.637255    204
# 51     2015-02        1  4.041667     24
# 52     2015-03        0  3.674757    206
# 53     2015-03        1  3.705882     51
# 54     2015-04        0  3.681564    179
# 55     2015-04        1  3.638889     36
# 56     2015-05        0  3.691099    191
# 57     2015-05        1  3.500000     34
# 58     2015-06        0  3.656410    195
# 59     2015-06        1  3.785714     42
# 60     2015-07        0  3.626943    193
# 61     2015-07        1  3.694444     36
# 62     2015-08        0  3.642857    196
# 63     2015-08        1  3.333333     33
# 64     2015-09        0  3.704082    196
# 65     2015-09        1  3.777778     36
# 66     2015-10        0  3.538462    208
# 67     2015-10        1  3.571429     42
# 68     2015-11        0  3.613260    181
# 69     2015-11        1  3.517241     29
# 70     2015-12        0  3.593333    150
# 71     2015-12        1  3.846154     26
# 72     2016-01        0  3.740196    204
# 73     2016-01        1  3.606061     33
# 74     2016-02        0  3.891626    203
# 75     2016-02        1  3.837209     43
# 76     2016-03        0  3.625592    211
# 77     2016-03        1  4.058824     34
# 78     2016-04        0  3.722727    220
# 79     2016-04        1  3.800000     45
# 80     2016-05        0  3.605263    190
# 81     2016-05        1  3.923077     52
# 82     2016-06        0  3.574661    221
# 83     2016-06        1  3.641509     53
# 84     2016-07        0  3.712389    226
# 85     2016-07        1  3.837209     43
# 86     2016-08        0  3.688645    273
# 87     2016-08        1  4.200000     40
# 88     2016-09        0  3.644195    267
# 89     2016-09        1  3.472222     36
# 90     2016-10        0  3.524664    223
# 176    2020-05        0  3.239819    221
# 177    2020-05        1  3.580000     50
# 178    2020-06        0  3.106122    245
# 179    2020-06        1  3.392857     28
# 180    2020-07        0  3.343066    274
# 181    2020-07        1  3.277778     36
# 182    2020-08        0  3.093617    235
# 183    2020-08        1  3.437500     32
# 184    2020-09        0  2.984906    265
# 185    2020-09        1  3.125000     40
# 186    2020-10        0  2.955882    204
# 187    2020-10        1  3.628571     35
# 188    2020-11        0  2.933735    166
# 189    2020-11        1  3.351351     37
# 190    2020-12        0  3.151163    172
# 191    2020-12        1  2.857143     28

# %%
figure(figsize=(12, 8), dpi=80)
sns.lineplot(data=comp, x='month_year', y='mean', hue = 'seattle', linewidth=2, style = 'seattle')
plt.title("Overall Job Satisfaction", fontsize=20)
plt.xlabel('Time', fontsize=20)
plt.ylabel('Average Rating', fontsize=20)
#ticks, labels = plt.xticks()

plt.xticks(ticks=[6,18,30,42,54,66,78,90], labels=['2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020'])
plt.legend(['Not Seattle', 'Seattle'])
plt.axvline(x=27, color = 'black')

# %%
f = df[df.company_name.isin(['Amazon.com', 'Walmart', 'McDonalds', 'Starbucks'])]
domp = f.groupby(['month_year', 'company_name']).agg({'overall_rating':['mean', 'count']})
domp.columns = ['mean', 'count']
domp.reset_index(inplace=True)
domp
# Out:
#     month_year company_name      mean  count
# 0      2013-01   Amazon.com  4.000000      9
# 1      2013-01    McDonalds  3.588235     17
# 2      2013-01    Starbucks  4.000000      7
# 3      2013-01      Walmart  3.181818     11
# 4      2013-02   Amazon.com  4.142857      7
# 5      2013-02    McDonalds  3.000000     10
# 6      2013-02    Starbucks  4.000000      6
# 7      2013-02      Walmart  3.500000     12
# 8      2013-03   Amazon.com  3.666667      6
# 9      2013-03    McDonalds  3.800000      5
# 10     2013-03    Starbucks  4.500000      8
# 11     2013-03      Walmart  3.923077     13
# 12     2013-04   Amazon.com  3.714286      7
# 13     2013-04    McDonalds  3.500000      6
# 14     2013-04    Starbucks  4.166667      6
# 15     2013-04      Walmart  2.625000      8
# 16     2013-05   Amazon.com  3.666667      6
# 17     2013-05    McDonalds  4.250000      4
# 18     2013-05    Starbucks  3.500000      4
# 19     2013-05      Walmart  3.533333     15
# 20     2013-06   Amazon.com  4.000000      9
# 21     2013-06    McDonalds  2.888889      9
# 22     2013-06    Starbucks  4.200000      5
# 23     2013-06      Walmart  3.307692     13
# 24     2013-07   Amazon.com  4.000000      3
# 25     2013-07    McDonalds  3.166667     12
# 26     2013-07    Starbucks  4.500000      4
# 27     2013-07      Walmart  3.050000     20
# 28     2013-08   Amazon.com  4.000000      5
# 29     2013-08    McDonalds  3.133333     15
# 30     2013-08    Starbucks  4.000000      7
# 31     2013-08      Walmart  3.416667     12
# 32     2013-09   Amazon.com  4.250000      8
# 33     2013-09    McDonalds  2.500000      6
# 34     2013-09    Starbucks  4.333333      6
# 35     2013-09      Walmart  3.500000     12
# 36     2013-10   Amazon.com  3.333333      3
# 37     2013-10    McDonalds  4.000000      9
# 38     2013-10    Starbucks  4.500000      6
# 39     2013-10      Walmart  3.923077     13
# 40     2013-11   Amazon.com  2.333333      3

plt.xlabel('Time', fontsize=20)
plt.ylabel('Average Rating', fontsize=20)
plt.legend(title='')
#ticks, labels = plt.xticks()

plt.xticks(ticks=[6,18,30,42,54,66,78,90], labels=['2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020'])
#plt.legend(['Not Seattle', 'Seattle'])
# Out:
# ([<matplotlib.axis.XTick at 0x7f6952768c10>,
#   <matplotlib.axis.XTick at 0x7f6952768d90>,
#   <matplotlib.axis.XTick at 0x7f6952762f90>,
#   <matplotlib.axis.XTick at 0x7f695445a090>,
#   <matplotlib.axis.XTick at 0x7f695446c390>,
#   <matplotlib.axis.XTick at 0x7f695446cc10>,
#   <matplotlib.axis.XTick at 0x7f695446e290>,
#   <matplotlib.axis.XTick at 0x7f695446e750>],
#  [Text(0, 0, '2013'),
#   Text(0, 0, '2014'),
#   Text(0, 0, '2015'),
#   Text(0, 0, '2016'),
#   Text(0, 0, '2017'),
#   Text(0, 0, '2018'),
#   Text(0, 0, '2019'),
#   Text(0, 0, '2020')])

# %%
df2 = df[df.compensation_rating!=0]
print(df2.shape[0])
comp = df2.groupby(['review_year', 'seattle']).agg({'compensation_rating':['mean', 'count']})
comp.columns = ['mean', 'count']
comp.reset_index(inplace=True)
comp
# Out:
# 36784
#     review_year  seattle      mean  count
# 0          2013        0  3.267055   1715
# 1          2013        1  3.585657    251
# 2          2014        0  3.191690   1805
# 3          2014        1  3.601881    319
# 4          2015        0  3.128922   2040
# 5          2015        1  3.471354    384
# 6          2016        0  3.233959   2556
# 7          2016        1  3.514523    482
# 8          2017        0  3.076155   6408
# 9          2017        1  3.473538   1077
# 10         2018        0  3.048751   6605
# 11         2018        1  3.568499   1219
# 12         2019        0  2.964241   6432
# 13         2019        1  3.470078   1153
# 14         2020        0  3.055916   3702
# 15         2020        1  3.477987    636

# %%
fig, ax = plt.subplots(figsize=(12, 8))
sns.barplot(data=comp, x='review_year', y='mean', hue='seattle')


plt.title("Compensation Satisfaction")
plt.xlabel('Year')
plt.ylabel('Average Rating')
#plt.legend(['Not Seattle', 'Seattle'])
plt.ylim(2.8, 3.8)
# Out:
# (2.8, 3.8)

# %%
r1 = df['review_date']<'01/01/2014'
r2 = (df['review_date']>= '01/01/2014') & (df['review_date']<'01/01/2015')
r3 = (df['review_date']>= '01/01/2015') & (df['review_date']<'04/15/2015')
r4 = (df['review_date']>= '04/15/2015') & (df['review_date']<'01/01/2016')
r5 = (df['review_date']>= '01/01/2016') & (df['review_date']<'01/01/2017')
r6 = (df['review_date']>= '01/01/2017') & (df['review_date']<'01/01/2018')
r7 = (df['review_date']>= '01/01/2018') & (df['review_date']<'01/01/2019')
r8 = (df['review_date']>= '01/01/2019') & (df['review_date']<'01/01/2020')
r9 = (df['review_date']>= '01/01/2020') & (df['review_date']<'01/01/2021')

df['range'] = 0
df.loc[r1, 'range'] ='2013'
df.loc[r2, 'range'] ='2014'
df.loc[r3, 'range'] ='2015A'
df.loc[r4, 'range'] ='2015B'
df.loc[r5, 'range'] ='2016'
df.loc[r6, 'range'] ='2017'
df.loc[r7, 'range'] ='2018'
df.loc[r8, 'range'] ='2019'
df.loc[r9, 'range'] ='2020'
df
# Out:
#       platform  scrape_company_num date_scraped  ... seattle month_year  range
# 0       Indeed                 187       5/8/21  ...       0    2016-09   2016
# 2       Indeed                  80       5/6/21  ...       0    2015-03  2015A
# 3       Indeed                 114      5/26/21  ...       0    2017-09   2017
# 4       Indeed                  90      5/15/21  ...       0    2016-12   2016
# 5       Indeed                   1      4/23/21  ...       0    2017-04   2017
# ...        ...                 ...          ...  ...     ...        ...    ...
# 42491   Indeed                  45       5/1/21  ...       0    2014-05   2014
# 42492   Indeed                  83      5/26/21  ...       0    2019-10   2019
# 42493   Indeed                 121      5/26/21  ...       0    2018-11   2018
# 42494   Indeed                  95      5/15/21  ...       0    2019-04   2019
# 42495   Indeed                 160       5/7/21  ...       0    2018-03   2018
#
# [39828 rows x 50 columns]

# %%
womp = df.groupby(['range', 'seattle']).agg({'overall_rating':['mean', 'count']})
womp.columns = ['mean', 'count']
womp.reset_index(inplace=True)
womp
# Out:
#     range  seattle      mean  count
# 0    2013        0  3.731805   2006
# 1    2013        1  3.846154    299
# 2    2014        0  3.711005   2090
# 3    2014        1  3.795640    367
# 4   2015A        0  3.682008    717
# 5   2015A        1  3.766423    137
# 6   2015B        0  3.641615   1610
# 7   2015B        1  3.623729    295
# 8    2016        0  3.659314   2856
# 9    2016        1  3.800000    535
# 10   2017        0  3.515693   6882
# 11   2017        1  3.680628   1146
# 12   2018        0  3.471455   6919
# 13   2018        1  3.618677   1285
# 14   2019        0  3.337538   6897
# 15   2019        1  3.549717   1237
# 16   2020        0  3.279825   3881
# 17   2020        1  3.448430    669

# %%
plt.clf()
fig, ax = plt.subplots(figsize=(20,8.27))
sns.barplot(data=womp, x='range', y='mean', hue='seattle')

plt.title('WASHINGTON')
plt.ylim(3.2, 4.1)
# Out:
# (3.2, 4.1)

# %%
# create output for R
df['post'] = 0
mask = (df['review_date']>='04/01/2015')
df.post[mask]=1


df['month_year'] = pd.to_datetime(df['review_date']).dt.to_period('M')

rdf = df[['overall_rating', 'work_life_rating', 'compensation_rating', 'job_security_rating',
          'management_rating', 'culture_rating', 'post', 'seattle', 'review_year', 
          'company_name', 'norm_job_title', 'review_date', 'city', 'month_year']]
rdf.to_csv('/content/drive/MyDrive/hannah_research/data/wash_rdf.csv', index=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %% [markdown]
# ### GIT COMMIT

# %%
#https://towardsdatascience.com/colaboratory-drive-github-the-workflow-made-simpler-bde89fba8a39

from google.colab import drive
from os.path import join

ROOT = '/content/drive'     # default for the drive
PROJ = 'My Drive/...'       # path to your project on Drive

GIT_USERNAME = "OlegZero13" # replace with yours
GIT_TOKEN = "XXX"           # definitely replace with yours
GIT_REPOSITORY = "yyy"      # ...nah


drive.mount(ROOT)           # we mount the drive at /content/drive

PROJECT_PATH = join(ROOT, PROJ)
# !mkdir "{PROJECT_PATH}"I    # in case we haven't created it already   

GIT_PATH = "https://{GIT_TOKEN}@github.com/{GIT_USERNAME}/{GIT_REPOSITORY}.git"
# !mkdir ./temp
# !git clone "{GIT_PATH}"
# !mv ./temp/* "{PROJECT_PATH}"
# !rm -rf ./temp
# !rsync -aP --exclude=data/ "{PROJECT_PATH}"/*  ./
